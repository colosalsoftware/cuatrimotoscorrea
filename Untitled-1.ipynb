# %%
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <meta name="description" content="Reserva tours en cuatrimoto en Medellín y disfruta de la mejor experiencia en la naturaleza. Explora planes, precios y reseñas aquí.">
    <meta name="keywords" content="cuatrimotos, tours en cuatrimoto, Medellín, aventura, reserva natural, planes en cuatrimoto">
    <meta name="author" content="Cuatrimotos Medellín">
    <title>Cuatrimotos Medellín - Tours y Aventura</title>
    
    <!-- Favicon -->
    <link rel="icon" href="./images/favicon.ico" type="image/x-icon">
    
    <!-- Bootstrap CSS -->
    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
    <!-- Estilos personalizados -->
    <link rel="stylesheet" href="./css/styles.css">
</head>
<body>
    <!-- Navegación -->
    <nav class="navbar navbar-expand-lg navbar-dark bg-success fixed-top">
        <div class="container">
            <a class="navbar-brand" href="#home">
                <img src="./images/logo_cuatrimotos.jpg" alt="Cuatrimotos Medellín" width="150">
            </a>
            <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
                <span class="navbar-toggler-icon"></span>
            </button>
            <div class="collapse navbar-collapse" id="navbarNav">
                <ul class="navbar-nav ml-auto">
                    <li class="nav-item"><a class="nav-link" href="#planes">Planes</a></li>
                    <li class="nav-item"><a class="nav-link" href="#galeria">Galería</a></li>
                    <li class="nav-item"><a class="nav-link" href="#ubicacion">Ubicación</a></li>
                    <li class="nav-item"><a class="nav-link" href="#pagos">Pagos</a></li>
                </ul>
            </div>
        </div>
    </nav>

    <!-- Hero -->
    <section id="home" class="bg-dark text-white text-center d-flex align-items-center" style="height: 100vh; background: url('./images/banner.jpg') center/cover;">
        <div class="container">
            <h1 class="display-4">Explora Medellín en Cuatrimoto</h1>
            <p class="lead">Vive una experiencia única en la naturaleza.</p>
            <a href="#planes" class="btn btn-success btn-lg">Ver Planes</a>
        </div>
    </section>

    <!-- Planes -->
    <section id="planes" class="py-5 bg-light">
        <div class="container">
            <h2 class="text-center mb-5">Planes Disponibles</h2>
            <div class="row">
                <!-- Plan Básico -->
                <div class="col-md-6">
                    <div class="card mb-4">
                        <img src="./images/plan_basico.jpg" class="card-img-top" alt="Plan Básico">
                        <div class="card-body text-center">
                            <h3>$190,000</h3>
                            <p>Con copiloto: $240,000</p>
                            <p>Incluye equipo de protección y guía instructor.</p>
                            <a href="https://wa.link/jyrz31" class="btn btn-primary">Reservar Ahora</a>
                        </div>
                    </div>
                </div>
                <!-- Plan Especial -->
                <div class="col-md-6">
                    <div class="card mb-4">
                        <img src="./images/plan_especial.jpg" class="card-img-top" alt="Plan Especial">
                        <div class="card-body text-center">
                            <h3>$240,000</h3>
                            <p>Con copiloto: $290,000</p>
                            <p>Incluye equipo de protección y guía instructor.</p>
                            <a href="https://wa.link/c3vmwr" class="btn btn-primary">Reservar Ahora</a>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </section>

    <!-- Galería -->
    <section id="galeria" class="py-5 bg-light">
        <div class="container">
            <h2 class="text-center mb-5">Galería</h2>
            <div class="row">
                <div class="col-md-4 mb-4">
                    <img src="./images/galeria_1.jpg" class="img-fluid rounded" alt="Galería 1">
                </div>
                <div class="col-md-4 mb-4">
                    <img src="./images/galeria_2.jpg" class="img-fluid rounded" alt="Galería 2">
                </div>
                <div class="col-md-4 mb-4">
                    <img src="./images/galeria_3.jpg" class="img-fluid rounded" alt="Galería 3">
                </div>
            </div>
        </div>
    </section>

    <!-- Ubicación -->
    <section id="ubicacion" class="py-5 bg-light">
        <div class="container">
            <h2 class="text-center mb-5">Ubicación</h2>
            <iframe src="https://www.google.com/maps/place/Cuatrimotos+Medellin+y+cabalgatas+en+Medellin/@6.0485323,-75.664859,17z/data=!3m1!4b1!4m6!3m5!1s0x8e46870012db2c1d:0xe8729d8f3000c6ac!8m2!3d6.0485323!4d-75.6622841" width="100%" height="450" style="border:0;" allowfullscreen="" loading="lazy"></iframe>
        </div>
    </section>

    <!-- Pagos -->
    <section id="pagos" class="py-5 bg-white">
        <div class="container">
            <h2 class="text-center mb-5">Información de Pago</h2>
            <p class="text-center">
                Cuenta de ahorros Bancolombia 👇🏻<br>
                <b>Número:</b> 00900008715<br>
                <b>Nombre:</b> Juan Camilo Cruz<br>
            </p>
        </div>
    </section>

    <!-- Scripts -->
    <script defer src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
    <script defer src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
</body>
</html>
